# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df1 = pd.read_csv('scenario_datta/zevm1.csv', index_col=0)
df1.index = pd.to_datetime(df1.index)

df2 = pd.read_csv('scenario_datta/zevm2.csv', index_col=0)
df2.index = pd.to_datetime(df2.index)

# %%
fig, ax = plt.subplots()

ax.plot(df1.total_kgCO2e_calc, c='blue')
ax.plot(df2.total_kgCO2e_calc, c='red')

# %%
df1.total_kgCO2e_calc.sum() - df2.total_kgCO2e_calc.sum()
# Out:
# 19901405888.46161
